# %% [markdown]
# exp 0 : Introduction to python

# %%
# anurag
print("anurag mahajan")
# Out:
# anurag mahajan

# %%
print(2)
# Out:
# 2

# %%
print([1,2,5])
# Out:
# [1, 2, 5]

# %%
x=2
y=[1,2,5]
z="anurag mahajan"
print(x,y,z,sep="\n")
# Out:
# 2
# [1, 2, 5]
# anurag mahajan
